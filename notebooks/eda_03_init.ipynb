# %%
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv()
os.chdir(os.getenv("ROOT_DIR"))

# %%
# --- PARAMS --- #
mode = 'sample'

# --- PATHS --- #
if mode == "sample":
	train_id_path = os.getenv("TRAIN_IDENTITY_SAMPLE_PATH")
if mode == "full":
	train_id_path = os.getenv("TRAIN_IDENTITY_PATH")

# %%
train_id = pd.read_csv(train_id_path)

# %%
train_id.head()
# Out:
#    TransactionID  id_01     id_02  id_03  id_04  id_05  id_06  id_07  id_08  \
# 0        3098499  -25.0  155682.0    0.0    0.0    4.0  -37.0   32.0  -36.0
# 1        3146061    0.0  180735.0    NaN    NaN    0.0    0.0    NaN    NaN
# 2        3063829   -5.0  194593.0    NaN    NaN    0.0    0.0    NaN    NaN
# 3        3106130  -20.0  175465.0    NaN    NaN    0.0    0.0    NaN    NaN
# 4        3398080  -35.0   84487.0    0.0    0.0    0.0    0.0    NaN    NaN
#
#    id_09  ...                    id_31  id_32      id_33           id_34  \
# 0    0.0  ...          Generic/Android   24.0        NaN  match_status:2
# 1    NaN  ...  chrome 63.0 for android    NaN        NaN             NaN
# 2    NaN  ...              chrome 63.0   24.0  2049x1152  match_status:2
# 3    NaN  ...       mobile safari 11.0    NaN        NaN             NaN
# 4    0.0  ...              chrome 65.0    NaN        NaN             NaN
#
#    id_35 id_36 id_37  id_38  DeviceType            DeviceInfo
# ...
